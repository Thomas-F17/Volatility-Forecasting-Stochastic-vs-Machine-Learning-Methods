# %% [markdown]
# # Appendix to Main Sections 4 and 5
#
# ## Selecting GARCH(1,1) and GJR-GARCH(1,1) Models for our analysis

# %% [markdown]
# ### Selecting GARCH models:
#
# * According to academic practice it is uncommon to estimate the GARCH model using a train/fvalidation/test split. Indeed, it is usually done using the full in-sample data (train + validation), this is because the parameters of GARCH are determined optimally through maximum likelihood.
# * Indeed, the GARCH model has economically interpretable parameters ($\alpha$ the ARCH term, $\beta$ the GARCH term and $\omega$ the long-run variance) and we find the parameters which maximise the likelihood of seeing our data:
#     * GARCH parameters maximise the probability of observing our historical data
# * Thus, using the QLIKE or MSE to select which model would perform best would lead to overfitting, this is because models with greater complexity are more likely to fit our data better and QLIKE and MSE do not entirely penalise for this complexity
# * On the other hand, metrics such as AIC (Akaike Information Criterion $\mathrm{AIC} = 2k - 2\ln\bigl(\hat{L}\bigr)$) or the BIC (Bayesian Information Criterion $\mathrm{BIC} = -2 \ln(\widehat{L}) + k \ln(n)$) which both penalise for complexity are more appropriate.
# * Indeed, as per p.41-43 [Ruey S. Tsay - "Analysis of Financial Time Series" (2nd Edition, 2005)](https://pzs.dstu.dp.ua/DataMining/times/bibl/Tsay.pdf) AIC and BIC are commonly used measures to select the lags in autoregressive processes - thus, we use both measures
# * More details on information criteria for model selection [MathWorks Information Criteria for Model Selection Documentation](https://www.mathworks.com/help/econ/information-criteria.html)

# %%
import arch
import numpy as np
import pandas as pd
import datetime
import yfinance as yf

# %%
Ticker = "MSFT"
# date format is "YYYY-MM-DD"
ins_start = "2015-01-01"
ins_end = "2019-12-31"
validation_start = "2020-01-01"
validation_end = "2021-12-31"
oos_start = '2022-01-01'
oos_end = '2025-11-01'

# %%
# Define a function to convert price data to continuously compounded daily returns

def ccr(Ticker, Start ,End):
    """
    Gets stock price data from Yahoo Finance and outputs continuously compounded daily returns.

    Parameters
    ----------
    Ticker : str
        The ticker symbol of the stock to analyze (e.g., 'AZN.L' for AstraZeneca plc).
    Start : str
        The start date for fetching data in 'YYYY-MM-DD' format.
    End : str
        The end date for fetching data in 'YYYY-MM-DD' format.
    
    Returns
    -------
    StockReturns : pandas series
        An array of continuously compounded daily returns.

    Notes
    -----
    A straightforward method for calculating continuously compounded returns

    Examples
    --------
    >>> ccr("AZN.L", "2020-01-01", "2023-12-31")
    """
    # Ensure Start and End are in datetime format
    Start = pd.to_datetime(Start) - pd.Timedelta(days=1)
    End = pd.to_datetime(End)

    # Fetch data from Yahoo Finance using yfinance
    Data = yf.download(Ticker, start=Start, end=End, auto_adjust=True, progress=False)['Close']
    
    # Calculate daily returns
    StockReturns = np.log(Data / Data.shift(1)).dropna()
    
    StockReturns = pd.DataFrame(StockReturns)
    
    StockReturns = StockReturns.set_axis(['Adj Close'], axis = 1)
        
    return StockReturns

# %%
from arch import arch_model

def garch_arch_library(returns, p=1, q=1, o=0, dist='normal'):
    """
    Estimate GARCH using arch library.
    """
    # Set up model
    if o == 0:
        model = arch_model(returns, vol='Garch', p=p, q=q, dist=dist)
    else:
        model = arch_model(returns, vol='Garch', p=p, o=o, q=q, dist=dist)
    
    # Fit
    fitted = model.fit(disp='off')
    
    # Extract parameters
    params = fitted.params
    
    # Print
    print(f"\n{'='*60}")
    print(f"ARCH Library: {'GJR-' if o>0 else ''}GARCH({p},{q}) with {dist}")
    print(f"{'='*60}")
    print(f"μ:  {params['mu']:.6f}")
    print(f"ω:  {params['omega']:.8f}")
    
    # Handle multiple alpha/beta for higher order models
    alpha_keys = [k for k in params.index if k.startswith('alpha')]
    beta_keys = [k for k in params.index if k.startswith('beta')]
    
    for key in alpha_keys:
        print(f"{key}:  {params[key]:.6f}")
    for key in beta_keys:
        print(f"{key}:  {params[key]:.6f}")
    
    if o > 0:
        gamma_keys = [k for k in params.index if k.startswith('gamma')]
        for key in gamma_keys:
            print(f"{key}:  {params[key]:.6f}")
    
    if dist == 't':
        print(f"ν:  {params['nu']:.2f}")
    
    # Calculate persistence
    persistence = sum([params[k] for k in alpha_keys]) + sum([params[k] for k in beta_keys])
    print(f"\nPersistence: {persistence:.4f}")
    print(f"AIC: {fitted.aic:.2f}")
    print(f"BIC: {fitted.bic:.2f}")
    print(f"{'='*60}\n")
    
    # Return fitted model object for forecasting
    return {
        'params': params,
        'aic': fitted.aic,
        'bic': fitted.bic,
        'variance': fitted.conditional_volatility**2,
        'residuals': fitted.resid,
        'model': fitted,  # Keep the fitted model for forecasting
        'long_run_var': fitted.params['omega'] / (1 - persistence)
    }
    
lags1 = []  # p (GARCH lags)
lags2 = []  # q (ARCH lags)
lags3 = []  # o (asymmetry lags)

for p in range(1, 6):
    for q in range(1, 6):
        for o in range(0,6):  # Standard GARCH
            lags1.append(p)
            lags2.append(q)
            lags3.append(o)  # Add asymmetric term


# Load returns ONCE (already rescaled × 100 in your code)
returns = ccr(Ticker, ins_start, validation_end) * 100

results = []

for idx, (p_val, q_val, o_val) in enumerate(zip(lags1, lags2, lags3), 1):
    try:
        model_name = f"GARCH({p_val},{q_val})" if o_val == 0 else f"GJR-GARCH({p_val},{o_val},{q_val})"
        
        print(f"\n{'#'*70}")
        print(f"MODEL {idx}/12: {model_name}")
        print(f"{'#'*70}")
        
        # arch library (use returns/100 since arch doesn't expect pre-scaled)
        arch_res = garch_arch_library(returns, p=p_val, q=q_val, o=o_val, dist='normal')
        
        # Store comparison
        results.append({
            'model': model_name,
            'p': p_val, 'q': q_val, 'o': o_val,
            'arch_aic': arch_res['aic'],
            'arch_bic': arch_res['bic']
        })
        
        print(f"\nError Metrics:")
        print(f" Arch AIC: {arch_res['aic']:.2f}")
        print(f" Arch BIC: {arch_res['bic']:.2f}")
        
    except Exception as e:
        print(f"\nERROR for {model_name}: {e}")
        print(f"Skipping this combination...\n")
        continue

# Summary
print("\n" + "="*80)
print("SUMMARY TABLE")
print("="*80)
if results:
    summary = pd.DataFrame(results)
    print(summary.to_string(index=False))
    
    best_arch = summary.loc[summary['arch_aic'].idxmin()]
    
    best_arch_bic = summary.loc[summary['arch_bic'].idxmin()]
    
    best_2_arch = summary.loc[summary['arch_aic'].nsmallest(2).index[-1]]
    
    best_2_arch_bic = summary.loc[summary['arch_bic'].nsmallest(2).index[-1]]
    
    print(f"Best model (arch):      {best_arch['model']} (AIC={best_arch['arch_aic']:.2f})")
    print(f"Best model (arch):      {best_arch_bic['model']} (BIC={best_arch_bic['arch_bic']:.2f})")
    
    print(f"2nd Best model (arch):      {best_2_arch['model']} (AIC={best_2_arch['arch_aic']:.2f})")
    print(f"2nd Best model (arch):      {best_2_arch_bic['model']} (BIC={best_2_arch_bic['arch_bic']:.2f})")
else:
    print("No successful estimations!")
# Out:
# ######################################################################
# MODEL 1/12: GARCH(1,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(1,1) with normal
# ============================================================
# μ:  0.139255
# ω:  0.26398567
# alpha[1]:  0.212369
# beta[1]:  0.702124
#
# Persistence: 0.9145
# AIC: 6366.19
# BIC: 6388.08
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6366.19
#  Arch BIC: 6388.08
#
# ######################################################################
# MODEL 2/12: GJR-GARCH(1,1,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,1) with normal
# ============================================================
# μ:  0.111237
# ω:  0.27228562
# alpha[1]:  0.119266
# beta[1]:  0.710911
# gamma[1]:  0.154020
#
# Persistence: 0.8302
# AIC: 6358.02
# BIC: 6385.39
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6358.02
#  Arch BIC: 6385.39
#
# ######################################################################
# MODEL 3/12: GJR-GARCH(1,2,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,1) with normal
# ============================================================
# μ:  0.111768
# ω:  0.27561097
# alpha[1]:  0.119988
# beta[1]:  0.707292
# gamma[1]:  0.144953
# gamma[2]:  0.012943
#
# Persistence: 0.8273
# AIC: 6359.98
# BIC: 6392.83
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6359.98
#  Arch BIC: 6392.83
#
# ######################################################################
# MODEL 4/12: GJR-GARCH(1,3,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,1) with normal
# ============================================================
# μ:  0.111773
# ω:  0.27558051
# alpha[1]:  0.120002
# beta[1]:  0.707298
# gamma[1]:  0.144925
# gamma[2]:  0.012960
# gamma[3]:  0.000000
#
# Persistence: 0.8273
# AIC: 6361.98
# BIC: 6400.30
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6361.98
#  Arch BIC: 6400.30
#
# ######################################################################
# MODEL 5/12: GJR-GARCH(1,4,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,1) with normal
# ============================================================
# μ:  0.111774
# ω:  0.27558998
# alpha[1]:  0.120001
# beta[1]:  0.707294
# gamma[1]:  0.144929
# gamma[2]:  0.012955
# gamma[3]:  0.000000
# gamma[4]:  0.000000
#
# Persistence: 0.8273
# AIC: 6363.98
# BIC: 6407.78
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6363.98
#  Arch BIC: 6407.78
#
# ######################################################################
# MODEL 6/12: GJR-GARCH(1,5,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,1) with normal
# ============================================================
# μ:  0.111774
# ω:  0.27557768
# alpha[1]:  0.120001
# beta[1]:  0.707299
# gamma[1]:  0.144934
# gamma[2]:  0.012961
# gamma[3]:  0.000000
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.8273
# AIC: 6365.98
# BIC: 6415.25
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6365.98
#  Arch BIC: 6415.25
#
# ######################################################################
# MODEL 7/12: GARCH(1,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(1,2) with normal
# ============================================================
# μ:  0.139256
# ω:  0.26396276
# alpha[1]:  0.212369
# beta[1]:  0.702132
# beta[2]:  0.000000
#
# Persistence: 0.9145
# AIC: 6368.19
# BIC: 6395.56
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6368.19
#  Arch BIC: 6395.56
#
# ######################################################################
# MODEL 8/12: GJR-GARCH(1,1,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,2) with normal
# ============================================================
# μ:  0.111227
# ω:  0.27229009
# alpha[1]:  0.119268
# beta[1]:  0.710910
# beta[2]:  0.000000
# gamma[1]:  0.154024
#
# Persistence: 0.8302
# AIC: 6360.02
# BIC: 6392.87
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6360.02
#  Arch BIC: 6392.87
#
# ######################################################################
# MODEL 9/12: GJR-GARCH(1,2,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,2) with normal
# ============================================================
# μ:  0.112899
# ω:  0.38950883
# alpha[1]:  0.169710
# beta[1]:  0.217009
# beta[2]:  0.362704
# gamma[1]:  0.058809
# gamma[2]:  0.181832
#
# Persistence: 0.7494
# AIC: 6358.97
# BIC: 6397.29
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6358.97
#  Arch BIC: 6397.29
#
# ######################################################################
# MODEL 10/12: GJR-GARCH(1,3,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,2) with normal
# ============================================================
# μ:  0.112888
# ω:  0.38952439
# alpha[1]:  0.169712
# beta[1]:  0.217001
# beta[2]:  0.362702
# gamma[1]:  0.058838
# gamma[2]:  0.181842
# gamma[3]:  0.000000
#
# Persistence: 0.7494
# AIC: 6360.97
# BIC: 6404.76
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6360.97
#  Arch BIC: 6404.76
#
# ######################################################################
# MODEL 11/12: GJR-GARCH(1,4,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,2) with normal
# ============================================================
# μ:  0.112889
# ω:  0.38948481
# alpha[1]:  0.169717
# beta[1]:  0.217004
# beta[2]:  0.362719
# gamma[1]:  0.058820
# gamma[2]:  0.181828
# gamma[3]:  0.000000
# gamma[4]:  0.000000
#
# Persistence: 0.7494
# AIC: 6362.97
# BIC: 6412.24
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6362.97
#  Arch BIC: 6412.24
#
# ######################################################################
# MODEL 12/12: GJR-GARCH(1,5,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,2) with normal
# ============================================================
# μ:  0.112889
# ω:  0.38953730
# alpha[1]:  0.169731
# beta[1]:  0.216997
# beta[2]:  0.362706
# gamma[1]:  0.058826
# gamma[2]:  0.181811
# gamma[3]:  0.000000
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.7494
# AIC: 6364.97
# BIC: 6419.71
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6364.97
#  Arch BIC: 6419.71
#
# ######################################################################
# MODEL 13/12: GARCH(1,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(1,3) with normal
# ============================================================
# μ:  0.139255
# ω:  0.26399447
# alpha[1]:  0.212372
# beta[1]:  0.702117
# beta[2]:  0.000000
# beta[3]:  0.000000
#
# Persistence: 0.9145
# AIC: 6370.19
# BIC: 6403.03
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6370.19
#  Arch BIC: 6403.03
#
# ######################################################################
# MODEL 14/12: GJR-GARCH(1,1,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,3) with normal
# ============================================================
# μ:  0.111236
# ω:  0.27227589
# alpha[1]:  0.119270
# beta[1]:  0.710915
# beta[2]:  0.000000
# beta[3]:  0.000000
# gamma[1]:  0.154013
#
# Persistence: 0.8302
# AIC: 6362.02
# BIC: 6400.34
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6362.02
#  Arch BIC: 6400.34
#
# ######################################################################
# MODEL 15/12: GJR-GARCH(1,2,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,3) with normal
# ============================================================
# μ:  0.109846
# ω:  0.41588851
# alpha[1]:  0.167675
# beta[1]:  0.070860
# beta[2]:  0.162720
# beta[3]:  0.306852
# gamma[1]:  0.097554
# gamma[2]:  0.205329
#
# Persistence: 0.7081
# AIC: 6357.41
# BIC: 6401.20
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6357.41
#  Arch BIC: 6401.20
#
# ######################################################################
# MODEL 16/12: GJR-GARCH(1,3,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,3) with normal
# ============================================================
# μ:  0.109685
# ω:  0.42010207
# alpha[1]:  0.164585
# beta[1]:  0.064877
# beta[2]:  0.140322
# beta[3]:  0.332060
# gamma[1]:  0.102950
# gamma[2]:  0.200688
# gamma[3]:  0.007485
#
# Persistence: 0.7018
# AIC: 6359.40
# BIC: 6408.67
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6359.40
#  Arch BIC: 6408.67
#
# ######################################################################
# MODEL 17/12: GJR-GARCH(1,4,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,3) with normal
# ============================================================
# μ:  0.111188
# ω:  0.45475770
# alpha[1]:  0.150095
# beta[1]:  0.064402
# beta[2]:  0.000000
# beta[3]:  0.446888
# gamma[1]:  0.120424
# gamma[2]:  0.172534
# gamma[3]:  0.044081
# gamma[4]:  0.025230
#
# Persistence: 0.6614
# AIC: 6361.11
# BIC: 6415.85
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6361.11
#  Arch BIC: 6415.85
#
# ######################################################################
# MODEL 18/12: GJR-GARCH(1,5,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,3) with normal
# ============================================================
# μ:  0.111188
# ω:  0.45476856
# alpha[1]:  0.150091
# beta[1]:  0.064401
# beta[2]:  0.000000
# beta[3]:  0.446888
# gamma[1]:  0.120439
# gamma[2]:  0.172545
# gamma[3]:  0.044072
# gamma[4]:  0.025231
# gamma[5]:  0.000000
#
# Persistence: 0.6614
# AIC: 6363.11
# BIC: 6423.32
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6363.11
#  Arch BIC: 6423.32
#
# ######################################################################
# MODEL 19/12: GARCH(1,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(1,4) with normal
# ============================================================
# μ:  0.139255
# ω:  0.26399228
# alpha[1]:  0.212375
# beta[1]:  0.702117
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
#
# Persistence: 0.9145
# AIC: 6372.19
# BIC: 6410.51
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6372.19
#  Arch BIC: 6410.51
#
# ######################################################################
# MODEL 20/12: GJR-GARCH(1,1,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,4) with normal
# ============================================================
# μ:  0.111238
# ω:  0.27225952
# alpha[1]:  0.119257
# beta[1]:  0.710930
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# gamma[1]:  0.154016
#
# Persistence: 0.8302
# AIC: 6364.02
# BIC: 6407.81
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6364.02
#  Arch BIC: 6407.81
#
# ######################################################################
# MODEL 21/12: GJR-GARCH(1,2,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,4) with normal
# ============================================================
# μ:  0.109853
# ω:  0.41588935
# alpha[1]:  0.167686
# beta[1]:  0.070858
# beta[2]:  0.162754
# beta[3]:  0.306824
# beta[4]:  0.000000
# gamma[1]:  0.097527
# gamma[2]:  0.205313
#
# Persistence: 0.7081
# AIC: 6359.41
# BIC: 6408.68
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6359.41
#  Arch BIC: 6408.68
#
# ######################################################################
# MODEL 22/12: GJR-GARCH(1,3,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,4) with normal
# ============================================================
# μ:  0.109682
# ω:  0.42010041
# alpha[1]:  0.164584
# beta[1]:  0.064878
# beta[2]:  0.140329
# beta[3]:  0.332054
# beta[4]:  0.000000
# gamma[1]:  0.102944
# gamma[2]:  0.200692
# gamma[3]:  0.007486
#
# Persistence: 0.7018
# AIC: 6361.40
# BIC: 6416.14
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6361.40
#  Arch BIC: 6416.14
#
# ######################################################################
# MODEL 23/12: GJR-GARCH(1,4,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,4) with normal
# ============================================================
# μ:  0.111184
# ω:  0.45479162
# alpha[1]:  0.150094
# beta[1]:  0.064379
# beta[2]:  0.000000
# beta[3]:  0.446890
# beta[4]:  0.000000
# gamma[1]:  0.120436
# gamma[2]:  0.172562
# gamma[3]:  0.044076
# gamma[4]:  0.025232
#
# Persistence: 0.6614
# AIC: 6363.11
# BIC: 6423.32
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6363.11
#  Arch BIC: 6423.32
#
# ######################################################################
# MODEL 24/12: GJR-GARCH(1,5,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,4) with normal
# ============================================================
# μ:  0.111190
# ω:  0.45474602
# alpha[1]:  0.150075
# beta[1]:  0.064404
# beta[2]:  0.000000
# beta[3]:  0.446896
# beta[4]:  0.000000
# gamma[1]:  0.120449
# gamma[2]:  0.172561
# gamma[3]:  0.044080
# gamma[4]:  0.025212
# gamma[5]:  0.000000
#
# Persistence: 0.6614
# AIC: 6365.11
# BIC: 6430.80
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6365.11
#  Arch BIC: 6430.80
#
# ######################################################################
# MODEL 25/12: GARCH(1,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(1,5) with normal
# ============================================================
# μ:  0.139260
# ω:  0.26397896
# alpha[1]:  0.212370
# beta[1]:  0.702124
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.000000
#
# Persistence: 0.9145
# AIC: 6374.19
# BIC: 6417.98
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6374.19
#  Arch BIC: 6417.98
#
# ######################################################################
# MODEL 26/12: GJR-GARCH(1,1,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,5) with normal
# ============================================================
# μ:  0.111236
# ω:  0.27227605
# alpha[1]:  0.119265
# beta[1]:  0.710917
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.154019
#
# Persistence: 0.8302
# AIC: 6366.02
# BIC: 6415.29
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6366.02
#  Arch BIC: 6415.29
#
# ######################################################################
# MODEL 27/12: GJR-GARCH(1,2,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,5) with normal
# ============================================================
# μ:  0.109827
# ω:  0.41589594
# alpha[1]:  0.167678
# beta[1]:  0.070872
# beta[2]:  0.162726
# beta[3]:  0.306844
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.097579
# gamma[2]:  0.205295
#
# Persistence: 0.7081
# AIC: 6361.41
# BIC: 6416.15
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6361.41
#  Arch BIC: 6416.15
#
# ######################################################################
# MODEL 28/12: GJR-GARCH(1,3,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,5) with normal
# ============================================================
# μ:  0.109676
# ω:  0.42008562
# alpha[1]:  0.164627
# beta[1]:  0.064890
# beta[2]:  0.140551
# beta[3]:  0.331816
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.102899
# gamma[2]:  0.200772
# gamma[3]:  0.007433
#
# Persistence: 0.7019
# AIC: 6363.40
# BIC: 6423.61
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6363.40
#  Arch BIC: 6423.61
#
# ######################################################################
# MODEL 29/12: GJR-GARCH(1,4,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,5) with normal
# ============================================================
# μ:  0.111180
# ω:  0.45474424
# alpha[1]:  0.150097
# beta[1]:  0.064437
# beta[2]:  0.000000
# beta[3]:  0.446868
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.120442
# gamma[2]:  0.172517
# gamma[3]:  0.044072
# gamma[4]:  0.025223
#
# Persistence: 0.6614
# AIC: 6365.11
# BIC: 6430.80
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6365.11
#  Arch BIC: 6430.80
#
# ######################################################################
# MODEL 30/12: GJR-GARCH(1,5,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(1,5) with normal
# ============================================================
# μ:  0.109683
# ω:  0.42008896
# alpha[1]:  0.164584
# beta[1]:  0.064890
# beta[2]:  0.140373
# beta[3]:  0.332011
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.102927
# gamma[2]:  0.200697
# gamma[3]:  0.007474
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.7019
# AIC: 6367.40
# BIC: 6438.56
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6367.40
#  Arch BIC: 6438.56
#
# ######################################################################
# MODEL 31/12: GARCH(2,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(2,1) with normal
# ============================================================
# μ:  0.140404
# ω:  0.27130358
# alpha[1]:  0.204560
# alpha[2]:  0.014882
# beta[1]:  0.693200
#
# Persistence: 0.9126
# AIC: 6368.11
# BIC: 6395.48
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6368.11
#  Arch BIC: 6395.48
#
# ######################################################################
# MODEL 32/12: GJR-GARCH(2,1,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,1) with normal
# ============================================================
# μ:  0.112728
# ω:  0.29006038
# alpha[1]:  0.101042
# alpha[2]:  0.030821
# beta[1]:  0.689658
# gamma[1]:  0.162264
#
# Persistence: 0.8215
# AIC: 6359.66
# BIC: 6392.50
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6359.66
#  Arch BIC: 6392.50
#
# ######################################################################
# MODEL 33/12: GJR-GARCH(2,2,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,1) with normal
# ============================================================
# μ:  0.112795
# ω:  0.29056366
# alpha[1]:  0.101505
# alpha[2]:  0.030170
# beta[1]:  0.689171
# gamma[1]:  0.159888
# gamma[2]:  0.003440
#
# Persistence: 0.8208
# AIC: 6361.66
# BIC: 6399.98
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6361.66
#  Arch BIC: 6399.98
#
# ######################################################################
# MODEL 34/12: GJR-GARCH(2,3,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,1) with normal
# ============================================================
# μ:  0.112797
# ω:  0.29056761
# alpha[1]:  0.101504
# alpha[2]:  0.030173
# beta[1]:  0.689162
# gamma[1]:  0.159887
# gamma[2]:  0.003450
# gamma[3]:  0.000000
#
# Persistence: 0.8208
# AIC: 6363.66
# BIC: 6407.45
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6363.66
#  Arch BIC: 6407.45
#
# ######################################################################
# MODEL 35/12: GJR-GARCH(2,4,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,1) with normal
# ============================================================
# μ:  0.112793
# ω:  0.29056561
# alpha[1]:  0.101500
# alpha[2]:  0.030149
# beta[1]:  0.689185
# gamma[1]:  0.159896
# gamma[2]:  0.003436
# gamma[3]:  0.000000
# gamma[4]:  0.000000
#
# Persistence: 0.8208
# AIC: 6365.66
# BIC: 6414.92
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6365.66
#  Arch BIC: 6414.92
#
# ######################################################################
# MODEL 36/12: GJR-GARCH(2,5,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,1) with normal
# ============================================================
# μ:  0.112794
# ω:  0.29056621
# alpha[1]:  0.101508
# alpha[2]:  0.030161
# beta[1]:  0.689168
# gamma[1]:  0.159899
# gamma[2]:  0.003447
# gamma[3]:  0.000000
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.8208
# AIC: 6367.66
# BIC: 6422.40
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6367.66
#  Arch BIC: 6422.40
#
# ######################################################################
# MODEL 37/12: GARCH(2,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(2,2) with normal
# ============================================================
# μ:  0.138167
# ω:  0.43244134
# alpha[1]:  0.217893
# alpha[2]:  0.128503
# beta[1]:  0.060246
# beta[2]:  0.452942
#
# Persistence: 0.8596
# AIC: 6370.12
# BIC: 6402.96
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6370.12
#  Arch BIC: 6402.96
#
# ######################################################################
# MODEL 38/12: GJR-GARCH(2,1,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,2) with normal
# ============================================================
# μ:  0.112733
# ω:  0.29006575
# alpha[1]:  0.101037
# alpha[2]:  0.030832
# beta[1]:  0.689655
# beta[2]:  0.000000
# gamma[1]:  0.162265
#
# Persistence: 0.8215
# AIC: 6361.66
# BIC: 6399.98
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6361.66
#  Arch BIC: 6399.98
#
# ######################################################################
# MODEL 39/12: GJR-GARCH(2,2,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,2) with normal
# ============================================================
# μ:  0.113461
# ω:  0.41399824
# alpha[1]:  0.159131
# alpha[2]:  0.026862
# beta[1]:  0.156126
# beta[2]:  0.395083
# gamma[1]:  0.071540
# gamma[2]:  0.178890
#
# Persistence: 0.7372
# AIC: 6360.61
# BIC: 6404.40
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6360.61
#  Arch BIC: 6404.40
#
# ######################################################################
# MODEL 40/12: GJR-GARCH(2,3,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,2) with normal
# ============================================================
# μ:  0.113458
# ω:  0.41397691
# alpha[1]:  0.159136
# alpha[2]:  0.026862
# beta[1]:  0.156135
# beta[2]:  0.395086
# gamma[1]:  0.071540
# gamma[2]:  0.178875
# gamma[3]:  0.000000
#
# Persistence: 0.7372
# AIC: 6362.61
# BIC: 6411.87
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6362.61
#  Arch BIC: 6411.87
#
# ######################################################################
# MODEL 41/12: GJR-GARCH(2,4,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,2) with normal
# ============================================================
# μ:  0.113459
# ω:  0.41397442
# alpha[1]:  0.159138
# alpha[2]:  0.026864
# beta[1]:  0.156129
# beta[2]:  0.395089
# gamma[1]:  0.071536
# gamma[2]:  0.178878
# gamma[3]:  0.000000
# gamma[4]:  0.000000
#
# Persistence: 0.7372
# AIC: 6364.61
# BIC: 6419.35
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6364.61
#  Arch BIC: 6419.35
#
# ######################################################################
# MODEL 42/12: GJR-GARCH(2,5,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,2) with normal
# ============================================================
# μ:  0.113464
# ω:  0.41397723
# alpha[1]:  0.159130
# alpha[2]:  0.026860
# beta[1]:  0.156125
# beta[2]:  0.395097
# gamma[1]:  0.071533
# gamma[2]:  0.178880
# gamma[3]:  0.000000
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.7372
# AIC: 6366.61
# BIC: 6426.82
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6366.61
#  Arch BIC: 6426.82
#
# ######################################################################
# MODEL 43/12: GARCH(2,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(2,3) with normal
# ============================================================
# μ:  0.138164
# ω:  0.43244432
# alpha[1]:  0.217878
# alpha[2]:  0.128504
# beta[1]:  0.060155
# beta[2]:  0.453031
# beta[3]:  0.000000
#
# Persistence: 0.8596
# AIC: 6372.12
# BIC: 6410.44
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6372.12
#  Arch BIC: 6410.44
#
# ######################################################################
# MODEL 44/12: GJR-GARCH(2,1,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,3) with normal
# ============================================================
# μ:  0.112735
# ω:  0.29004822
# alpha[1]:  0.101036
# alpha[2]:  0.030829
# beta[1]:  0.689663
# beta[2]:  0.000000
# beta[3]:  0.000000
# gamma[1]:  0.162266
#
# Persistence: 0.8215
# AIC: 6363.66
# BIC: 6407.45
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6363.66
#  Arch BIC: 6407.45
#
# ######################################################################
# MODEL 45/12: GJR-GARCH(2,2,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,3) with normal
# ============================================================
# μ:  0.110436
# ω:  0.44484260
# alpha[1]:  0.165638
# alpha[2]:  0.023494
# beta[1]:  0.000000
# beta[2]:  0.196853
# beta[3]:  0.308904
# gamma[1]:  0.100181
# gamma[2]:  0.212984
#
# Persistence: 0.6949
# AIC: 6358.75
# BIC: 6408.02
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6358.75
#  Arch BIC: 6408.02
#
# ######################################################################
# MODEL 46/12: GJR-GARCH(2,3,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,3) with normal
# ============================================================
# μ:  0.110234
# ω:  0.45141957
# alpha[1]:  0.159841
# alpha[2]:  0.021280
# beta[1]:  0.000000
# beta[2]:  0.150973
# beta[3]:  0.350823
# gamma[1]:  0.107820
# gamma[2]:  0.205546
# gamma[3]:  0.016150
#
# Persistence: 0.6829
# AIC: 6360.66
# BIC: 6415.40
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6360.66
#  Arch BIC: 6415.40
#
# ######################################################################
# MODEL 47/12: GJR-GARCH(2,4,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,3) with normal
# ============================================================
# μ:  0.110235
# ω:  0.45144922
# alpha[1]:  0.159836
# alpha[2]:  0.021283
# beta[1]:  0.000000
# beta[2]:  0.150980
# beta[3]:  0.350807
# gamma[1]:  0.107831
# gamma[2]:  0.205545
# gamma[3]:  0.016147
# gamma[4]:  0.000000
#
# Persistence: 0.6829
# AIC: 6362.66
# BIC: 6422.87
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6362.66
#  Arch BIC: 6422.87
#
# ######################################################################
# MODEL 48/12: GJR-GARCH(2,5,3)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,3) with normal
# ============================================================
# μ:  0.110238
# ω:  0.45143215
# alpha[1]:  0.159849
# alpha[2]:  0.021284
# beta[1]:  0.000000
# beta[2]:  0.150978
# beta[3]:  0.350808
# gamma[1]:  0.107826
# gamma[2]:  0.205539
# gamma[3]:  0.016142
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.6829
# AIC: 6364.66
# BIC: 6430.35
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6364.66
#  Arch BIC: 6430.35
#
# ######################################################################
# MODEL 49/12: GARCH(2,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(2,4) with normal
# ============================================================
# μ:  0.138160
# ω:  0.43246667
# alpha[1]:  0.217895
# alpha[2]:  0.128487
# beta[1]:  0.060211
# beta[2]:  0.452964
# beta[3]:  0.000000
# beta[4]:  0.000000
#
# Persistence: 0.8596
# AIC: 6374.12
# BIC: 6417.91
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6374.12
#  Arch BIC: 6417.91
#
# ######################################################################
# MODEL 50/12: GJR-GARCH(2,1,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,4) with normal
# ============================================================
# μ:  0.112732
# ω:  0.29005853
# alpha[1]:  0.101036
# alpha[2]:  0.030825
# beta[1]:  0.689662
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# gamma[1]:  0.162267
#
# Persistence: 0.8215
# AIC: 6365.66
# BIC: 6414.93
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6365.66
#  Arch BIC: 6414.93
#
# ######################################################################
# MODEL 51/12: GJR-GARCH(2,2,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,4) with normal
# ============================================================
# μ:  0.110427
# ω:  0.44481022
# alpha[1]:  0.165614
# alpha[2]:  0.023490
# beta[1]:  0.000000
# beta[2]:  0.196823
# beta[3]:  0.308965
# beta[4]:  0.000000
# gamma[1]:  0.100180
# gamma[2]:  0.212950
#
# Persistence: 0.6949
# AIC: 6360.75
# BIC: 6415.50
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6360.75
#  Arch BIC: 6415.50
#
# ######################################################################
# MODEL 52/12: GJR-GARCH(2,3,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,4) with normal
# ============================================================
# μ:  0.110238
# ω:  0.45138643
# alpha[1]:  0.159841
# alpha[2]:  0.021280
# beta[1]:  0.000000
# beta[2]:  0.151006
# beta[3]:  0.350812
# beta[4]:  0.000000
# gamma[1]:  0.107809
# gamma[2]:  0.205538
# gamma[3]:  0.016139
#
# Persistence: 0.6829
# AIC: 6362.66
# BIC: 6422.87
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6362.66
#  Arch BIC: 6422.87
#
# ######################################################################
# MODEL 53/12: GJR-GARCH(2,4,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,4) with normal
# ============================================================
# μ:  0.110237
# ω:  0.45138571
# alpha[1]:  0.159831
# alpha[2]:  0.021279
# beta[1]:  0.000000
# beta[2]:  0.150946
# beta[3]:  0.350878
# beta[4]:  0.000000
# gamma[1]:  0.107819
# gamma[2]:  0.205511
# gamma[3]:  0.016155
# gamma[4]:  0.000000
#
# Persistence: 0.6829
# AIC: 6364.66
# BIC: 6430.35
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6364.66
#  Arch BIC: 6430.35
#
# ######################################################################
# MODEL 54/12: GJR-GARCH(2,5,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,4) with normal
# ============================================================
# μ:  0.110239
# ω:  0.45141169
# alpha[1]:  0.159831
# alpha[2]:  0.021281
# beta[1]:  0.000000
# beta[2]:  0.150852
# beta[3]:  0.350958
# beta[4]:  0.000000
# gamma[1]:  0.107848
# gamma[2]:  0.205488
# gamma[3]:  0.016170
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.6829
# AIC: 6366.66
# BIC: 6437.82
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6366.66
#  Arch BIC: 6437.82
#
# ######################################################################
# MODEL 55/12: GARCH(2,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(2,5) with normal
# ============================================================
# μ:  0.138161
# ω:  0.43249781
# alpha[1]:  0.217894
# alpha[2]:  0.128544
# beta[1]:  0.060045
# beta[2]:  0.453080
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.000000
#
# Persistence: 0.8596
# AIC: 6376.12
# BIC: 6425.38
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6376.12
#  Arch BIC: 6425.38
#
# ######################################################################
# MODEL 56/12: GJR-GARCH(2,1,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,5) with normal
# ============================================================
# μ:  0.112741
# ω:  0.29008751
# alpha[1]:  0.101036
# alpha[2]:  0.030853
# beta[1]:  0.689634
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.162255
#
# Persistence: 0.8215
# AIC: 6367.66
# BIC: 6422.40
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6367.66
#  Arch BIC: 6422.40
#
# ######################################################################
# MODEL 57/12: GJR-GARCH(2,2,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,5) with normal
# ============================================================
# μ:  0.110432
# ω:  0.44484963
# alpha[1]:  0.165644
# alpha[2]:  0.023488
# beta[1]:  0.000000
# beta[2]:  0.196828
# beta[3]:  0.308938
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.100189
# gamma[2]:  0.212985
#
# Persistence: 0.6949
# AIC: 6362.75
# BIC: 6422.97
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6362.75
#  Arch BIC: 6422.97
#
# ######################################################################
# MODEL 58/12: GJR-GARCH(2,3,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,5) with normal
# ============================================================
# μ:  0.110233
# ω:  0.45140677
# alpha[1]:  0.159840
# alpha[2]:  0.021281
# beta[1]:  0.000000
# beta[2]:  0.150949
# beta[3]:  0.350858
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.107828
# gamma[2]:  0.205522
# gamma[3]:  0.016152
#
# Persistence: 0.6829
# AIC: 6364.66
# BIC: 6430.35
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6364.66
#  Arch BIC: 6430.35
#
# ######################################################################
# MODEL 59/12: GJR-GARCH(2,4,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,5) with normal
# ============================================================
# μ:  0.110239
# ω:  0.45141822
# alpha[1]:  0.159834
# alpha[2]:  0.021281
# beta[1]:  0.000000
# beta[2]:  0.150926
# beta[3]:  0.350868
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.107831
# gamma[2]:  0.205520
# gamma[3]:  0.016166
# gamma[4]:  0.000000
#
# Persistence: 0.6829
# AIC: 6366.66
# BIC: 6437.82
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6366.66
#  Arch BIC: 6437.82
#
# ######################################################################
# MODEL 60/12: GJR-GARCH(2,5,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(2,5) with normal
# ============================================================
# μ:  0.110246
# ω:  0.45134005
# alpha[1]:  0.159835
# alpha[2]:  0.021284
# beta[1]:  0.000000
# beta[2]:  0.150946
# beta[3]:  0.350893
# beta[4]:  0.000000
# beta[5]:  0.000000
# gamma[1]:  0.107784
# gamma[2]:  0.205526
# gamma[3]:  0.016156
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.6830
# AIC: 6368.66
# BIC: 6445.30
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6368.66
#  Arch BIC: 6445.30
#
# ######################################################################
# MODEL 61/12: GARCH(3,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(3,1) with normal
# ============================================================
# μ:  0.136866
# ω:  0.31991275
# alpha[1]:  0.205213
# alpha[2]:  0.000000
# alpha[3]:  0.056691
# beta[1]:  0.637085
#
# Persistence: 0.8990
# AIC: 6368.09
# BIC: 6400.94
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6368.09
#  Arch BIC: 6400.94
#
# ######################################################################
# MODEL 62/12: GJR-GARCH(3,1,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,1) with normal
# ============================================================
# μ:  0.101290
# ω:  0.36348791
# alpha[1]:  0.074395
# alpha[2]:  0.000000
# alpha[3]:  0.097989
# beta[1]:  0.599842
# gamma[1]:  0.230359
#
# Persistence: 0.7722
# AIC: 6354.23
# BIC: 6392.55
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6354.23
#  Arch BIC: 6392.55
#
# ######################################################################
# MODEL 63/12: GJR-GARCH(3,2,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,1) with normal
# ============================================================
# μ:  0.103304
# ω:  0.38879911
# alpha[1]:  0.069834
# alpha[2]:  0.000000
# alpha[3]:  0.109893
# beta[1]:  0.568245
# gamma[1]:  0.192390
# gamma[2]:  0.078816
#
# Persistence: 0.7480
# AIC: 6354.98
# BIC: 6398.77
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6354.98
#  Arch BIC: 6398.77
#
# ######################################################################
# MODEL 64/12: GJR-GARCH(3,3,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,1) with normal
# ============================================================
# μ:  0.117228
# ω:  0.34433813
# alpha[1]:  0.050943
# alpha[2]:  0.000000
# alpha[3]:  0.199866
# beta[1]:  0.572812
# gamma[1]:  0.200652
# gamma[2]:  0.169908
# gamma[3]:  -0.199866
#
# Persistence: 0.8236
# AIC: 6341.69
# BIC: 6390.96
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6341.69
#  Arch BIC: 6390.96
#
# ######################################################################
# MODEL 65/12: GJR-GARCH(3,4,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,1) with normal
# ============================================================
# μ:  0.117236
# ω:  0.34433331
# alpha[1]:  0.050951
# alpha[2]:  0.000000
# alpha[3]:  0.199873
# beta[1]:  0.572812
# gamma[1]:  0.200658
# gamma[2]:  0.169890
# gamma[3]:  -0.199873
# gamma[4]:  0.000000
#
# Persistence: 0.8236
# AIC: 6343.69
# BIC: 6398.43
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6343.69
#  Arch BIC: 6398.43
#
# ######################################################################
# MODEL 66/12: GJR-GARCH(3,5,1)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,1) with normal
# ============================================================
# μ:  0.117230
# ω:  0.34435041
# alpha[1]:  0.050943
# alpha[2]:  0.000000
# alpha[3]:  0.199858
# beta[1]:  0.572806
# gamma[1]:  0.200653
# gamma[2]:  0.169897
# gamma[3]:  -0.199858
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.8236
# AIC: 6345.69
# BIC: 6405.91
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6345.69
#  Arch BIC: 6405.91
#
# ######################################################################
# MODEL 67/12: GARCH(3,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(3,2) with normal
# ============================================================
# μ:  0.136871
# ω:  0.31990336
# alpha[1]:  0.205225
# alpha[2]:  0.000000
# alpha[3]:  0.056665
# beta[1]:  0.637106
# beta[2]:  0.000000
#
# Persistence: 0.8990
# AIC: 6370.09
# BIC: 6408.41
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6370.09
#  Arch BIC: 6408.41
#
# ######################################################################
# MODEL 68/12: GJR-GARCH(3,1,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,2) with normal
# ============================================================
# μ:  0.101290
# ω:  0.36350493
# alpha[1]:  0.074395
# alpha[2]:  0.000000
# alpha[3]:  0.097986
# beta[1]:  0.599840
# beta[2]:  0.000000
# gamma[1]:  0.230356
#
# Persistence: 0.7722
# AIC: 6356.23
# BIC: 6400.02
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6356.23
#  Arch BIC: 6400.02
#
# ######################################################################
# MODEL 69/12: GJR-GARCH(3,2,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,2) with normal
# ============================================================
# μ:  0.103305
# ω:  0.38879585
# alpha[1]:  0.069830
# alpha[2]:  0.000000
# alpha[3]:  0.109882
# beta[1]:  0.568251
# beta[2]:  0.000000
# gamma[1]:  0.192381
# gamma[2]:  0.078835
#
# Persistence: 0.7480
# AIC: 6356.98
# BIC: 6406.25
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6356.98
#  Arch BIC: 6406.25
#
# ######################################################################
# MODEL 70/12: GJR-GARCH(3,3,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,2) with normal
# ============================================================
# μ:  0.117236
# ω:  0.34434634
# alpha[1]:  0.050947
# alpha[2]:  0.000000
# alpha[3]:  0.199843
# beta[1]:  0.572809
# beta[2]:  0.000000
# gamma[1]:  0.200643
# gamma[2]:  0.169907
# gamma[3]:  -0.199843
#
# Persistence: 0.8236
# AIC: 6343.69
# BIC: 6398.43
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6343.69
#  Arch BIC: 6398.43
#
# ######################################################################
# MODEL 71/12: GJR-GARCH(3,4,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,2) with normal
# ============================================================
# μ:  0.117234
# ω:  0.34434563
# alpha[1]:  0.050954
# alpha[2]:  0.000000
# alpha[3]:  0.199855
# beta[1]:  0.572805
# beta[2]:  0.000000
# gamma[1]:  0.200643
# gamma[2]:  0.169889
# gamma[3]:  -0.199855
# gamma[4]:  0.000000
#
# Persistence: 0.8236
# AIC: 6345.69
# BIC: 6405.91
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6345.69
#  Arch BIC: 6405.91
#
# ######################################################################
# MODEL 72/12: GJR-GARCH(3,5,2)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(3,2) with normal
# ============================================================
# μ:  0.117232
# ω:  0.34436348
# alpha[1]:  0.050945
# alpha[2]:  0.000000
# alpha[3]:  0.199852
# beta[1]:  0.572808
# beta[2]:  0.000000
# gamma[1]:  0.200669
# gamma[2]:  0.169872
# gamma[3]:  -0.199852
# gamma[4]:  0.000000
# gamma[5]:  0.000000
#
# Persistence: 0.8236
# AIC: 6347.69
# BIC: 6413.38
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6347.69
#  Arch BIC: 6413.38
#
# ######################################################################
# MODEL 73/12: GARCH(3,3)
# ######################################################################
#
# ...
# alpha[4]:  0.114490
# alpha[5]:  0.022765
# beta[1]:  0.427920
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# gamma[1]:  0.298781
#
# Persistence: 0.7053
# AIC: 6355.42
# BIC: 6421.12
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6355.42
#  Arch BIC: 6421.12
#
# ######################################################################
# MODEL 141/12: GJR-GARCH(5,2,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,4) with normal
# ============================================================
# μ:  0.103217
# ω:  0.72888268
# alpha[1]:  0.055485
# alpha[2]:  0.021609
# alpha[3]:  0.109255
# alpha[4]:  0.154393
# alpha[5]:  0.113064
# beta[1]:  0.000000
# beta[2]:  0.067727
# beta[3]:  0.028422
# beta[4]:  0.000000
# gamma[1]:  0.220945
# gamma[2]:  0.332294
#
# Persistence: 0.5500
# AIC: 6341.46
# BIC: 6412.63
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6341.46
#  Arch BIC: 6412.63
#
# ######################################################################
# MODEL 142/12: GJR-GARCH(5,3,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,4) with normal
# ============================================================
# μ:  0.105581
# ω:  0.69271258
# alpha[1]:  0.057984
# alpha[2]:  0.023443
# alpha[3]:  0.138780
# alpha[4]:  0.148056
# alpha[5]:  0.116884
# beta[1]:  0.000000
# beta[2]:  0.116320
# beta[3]:  0.000000
# beta[4]:  0.000000
# gamma[1]:  0.226504
# gamma[2]:  0.336172
# gamma[3]:  -0.076836
#
# Persistence: 0.6015
# AIC: 6341.78
# BIC: 6418.42
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6341.78
#  Arch BIC: 6418.42
#
# ######################################################################
# MODEL 143/12: GJR-GARCH(5,4,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,4) with normal
# ============================================================
# μ:  0.109945
# ω:  0.63561299
# alpha[1]:  0.056526
# alpha[2]:  0.022249
# alpha[3]:  0.146761
# alpha[4]:  0.163236
# alpha[5]:  0.101653
# beta[1]:  0.000000
# beta[2]:  0.171814
# beta[3]:  0.000000
# beta[4]:  0.000000
# gamma[1]:  0.223125
# gamma[2]:  0.353725
# gamma[3]:  -0.094819
# gamma[4]:  -0.091382
#
# Persistence: 0.6622
# AIC: 6342.39
# BIC: 6424.50
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6342.39
#  Arch BIC: 6424.50
#
# ######################################################################
# MODEL 144/12: GJR-GARCH(5,5,4)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,4) with normal
# ============================================================
# μ:  0.120485
# ω:  0.68063657
# alpha[1]:  0.059984
# alpha[2]:  0.026780
# alpha[3]:  0.147386
# alpha[4]:  0.190709
# alpha[5]:  0.206553
# beta[1]:  0.000000
# beta[2]:  0.000000
# beta[3]:  0.079294
# beta[4]:  0.000000
# gamma[1]:  0.227689
# gamma[2]:  0.341220
# gamma[3]:  -0.046876
# gamma[4]:  -0.033572
# gamma[5]:  -0.186428
#
# Persistence: 0.7107
# AIC: 6336.25
# BIC: 6423.83
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6336.25
#  Arch BIC: 6423.83
#
# ######################################################################
# MODEL 145/12: GARCH(5,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GARCH(5,5) with normal
# ============================================================
# μ:  0.137591
# ω:  0.73979964
# alpha[1]:  0.218908
# alpha[2]:  0.117821
# alpha[3]:  0.096730
# alpha[4]:  0.124761
# alpha[5]:  0.072607
# beta[1]:  0.000000
# beta[2]:  0.000000
# beta[3]:  0.145932
# beta[4]:  0.000000
# beta[5]:  0.000000
#
# Persistence: 0.7768
# AIC: 6371.85
# BIC: 6437.54
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6371.85
#  Arch BIC: 6437.54
#
# ######################################################################
# MODEL 146/12: GJR-GARCH(5,1,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,5) with normal
# ============================================================
# μ:  0.096459
# ω:  0.49142674
# alpha[1]:  0.066105
# alpha[2]:  0.007606
# alpha[3]:  0.062512
# alpha[4]:  0.116206
# alpha[5]:  0.015047
# beta[1]:  0.413543
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.022619
# gamma[1]:  0.304484
#
# Persistence: 0.7036
# AIC: 6356.82
# BIC: 6427.98
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6356.82
#  Arch BIC: 6427.98
#
# ######################################################################
# MODEL 147/12: GJR-GARCH(5,2,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,5) with normal
# ============================================================
# μ:  0.104330
# ω:  0.70093728
# alpha[1]:  0.050227
# alpha[2]:  0.022239
# alpha[3]:  0.120248
# alpha[4]:  0.156359
# alpha[5]:  0.105963
# beta[1]:  0.000000
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.087902
# gamma[1]:  0.208996
# gamma[2]:  0.381905
#
# Persistence: 0.5429
# AIC: 6336.91
# BIC: 6413.55
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6336.91
#  Arch BIC: 6413.55
#
# ######################################################################
# MODEL 148/12: GJR-GARCH(5,3,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,5) with normal
# ============================================================
# μ:  0.105897
# ω:  0.69428668
# alpha[1]:  0.052396
# alpha[2]:  0.023826
# alpha[3]:  0.137117
# alpha[4]:  0.158099
# alpha[5]:  0.108101
# beta[1]:  0.000000
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.085938
# gamma[1]:  0.207692
# gamma[2]:  0.383372
# gamma[3]:  -0.034007
#
# Persistence: 0.5655
# AIC: 6338.51
# BIC: 6420.63
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6338.51
#  Arch BIC: 6420.63
#
# ######################################################################
# MODEL 149/12: GJR-GARCH(5,4,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,5) with normal
# ============================================================
# μ:  0.108137
# ω:  0.68827540
# alpha[1]:  0.051282
# alpha[2]:  0.024463
# alpha[3]:  0.143627
# alpha[4]:  0.173343
# alpha[5]:  0.105969
# beta[1]:  0.000000
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.089621
# gamma[1]:  0.208772
# gamma[2]:  0.384883
# gamma[3]:  -0.036150
# gamma[4]:  -0.044780
#
# Persistence: 0.5883
# AIC: 6340.00
# BIC: 6427.58
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6340.00
#  Arch BIC: 6427.58
#
# ######################################################################
# MODEL 150/12: GJR-GARCH(5,5,5)
# ######################################################################
#
# ============================================================
# ARCH Library: GJR-GARCH(5,5) with normal
# ============================================================
# μ:  0.119775
# ω:  0.65229973
# alpha[1]:  0.052198
# alpha[2]:  0.028758
# alpha[3]:  0.157176
# alpha[4]:  0.197687
# alpha[5]:  0.206846
# beta[1]:  0.000000
# beta[2]:  0.000000
# beta[3]:  0.000000
# beta[4]:  0.000000
# beta[5]:  0.070545
# gamma[1]:  0.227597
# gamma[2]:  0.376309
# gamma[3]:  -0.049457
# gamma[4]:  -0.057216
# gamma[5]:  -0.162253
#
# Persistence: 0.7132
# AIC: 6334.15
# BIC: 6427.21
# ============================================================
#
#
# Error Metrics:
#  Arch AIC: 6334.15
#  Arch BIC: 6427.21
#
# ================================================================================
# SUMMARY TABLE
# ================================================================================
#            model  p  q  o    arch_aic    arch_bic
#       GARCH(1,1)  1  1  0 6366.187881 6388.084700
# GJR-GARCH(1,1,1)  1  1  1 6358.020760 6385.391784
# GJR-GARCH(1,2,1)  1  1  2 6359.981794 6392.827023
# GJR-GARCH(1,3,1)  1  1  3 6361.981793 6400.301227
# GJR-GARCH(1,4,1)  1  1  4 6363.981793 6407.775432
# GJR-GARCH(1,5,1)  1  1  5 6365.981793 6415.249637
#       GARCH(1,2)  1  2  0 6368.187881 6395.558905
# GJR-GARCH(1,1,2)  1  2  1 6360.020761 6392.865989
# GJR-GARCH(1,2,2)  1  2  2 6358.969892 6397.289326
# GJR-GARCH(1,3,2)  1  2  3 6360.969892 6404.763531
# GJR-GARCH(1,4,2)  1  2  4 6362.969892 6412.237735
# GJR-GARCH(1,5,2)  1  2  5 6364.969893 6419.711941
#       GARCH(1,3)  1  3  0 6370.187881 6403.033109
# GJR-GARCH(1,1,3)  1  3  1 6362.020760 6400.340194
# GJR-GARCH(1,2,3)  1  3  2 6357.407177 6401.200815
# GJR-GARCH(1,3,3)  1  3  3 6359.398517 6408.666361
# GJR-GARCH(1,4,3)  1  3  4 6361.108138 6415.850186
# GJR-GARCH(1,5,3)  1  3  5 6363.108138 6423.324390
#       GARCH(1,4)  1  4  0 6372.187881 6410.507314
# GJR-GARCH(1,1,4)  1  4  1 6364.020760 6407.814399
# GJR-GARCH(1,2,4)  1  4  2 6359.407176 6408.675020
# GJR-GARCH(1,3,4)  1  4  3 6361.398517 6416.140565
# GJR-GARCH(1,4,4)  1  4  4 6363.108138 6423.324390
# GJR-GARCH(1,5,4)  1  4  5 6365.108138 6430.798596
#       GARCH(1,5)  1  5  0 6374.187881 6417.981519
# GJR-GARCH(1,1,5)  1  5  1 6366.020760 6415.288603
# GJR-GARCH(1,2,5)  1  5  2 6361.407178 6416.149226
# GJR-GARCH(1,3,5)  1  5  3 6363.398519 6423.614772
# GJR-GARCH(1,4,5)  1  5  4 6365.108138 6430.798596
# GJR-GARCH(1,5,5)  1  5  5 6367.398517 6438.563180
#       GARCH(2,1)  2  1  0 6368.109501 6395.480525
# GJR-GARCH(2,1,1)  2  1  1 6359.658609 6392.503838
# GJR-GARCH(2,2,1)  2  1  2 6361.656012 6399.975445
# GJR-GARCH(2,3,1)  2  1  3 6363.656012 6407.449650
# GJR-GARCH(2,4,1)  2  1  4 6365.656012 6414.923855
# GJR-GARCH(2,5,1)  2  1  5 6367.656012 6422.398060
#       GARCH(2,2)  2  2  0 6370.116986 6402.962215
# GJR-GARCH(2,1,2)  2  2  1 6361.658608 6399.978042
# GJR-GARCH(2,2,2)  2  2  2 6360.607129 6404.400767
# GJR-GARCH(2,3,2)  2  2  3 6362.607129 6411.874972
# GJR-GARCH(2,4,2)  2  2  4 6364.607129 6419.349177
# GJR-GARCH(2,5,2)  2  2  5 6366.607129 6426.823382
#       GARCH(2,3)  2  3  0 6372.116986 6410.436419
# GJR-GARCH(2,1,3)  2  3  1 6363.658609 6407.452247
# GJR-GARCH(2,2,3)  2  3  2 6358.753676 6408.021519
# GJR-GARCH(2,3,3)  2  3  3 6360.657431 6415.399479
# GJR-GARCH(2,4,3)  2  3  4 6362.657431 6422.873684
# GJR-GARCH(2,5,3)  2  3  5 6364.657431 6430.347889
#       GARCH(2,4)  2  4  0 6374.116986 6417.910624
# GJR-GARCH(2,1,4)  2  4  1 6365.658608 6414.926452
# GJR-GARCH(2,2,4)  2  4  2 6360.753678 6415.495726
# GJR-GARCH(2,3,4)  2  4  3 6362.657431 6422.873683
# GJR-GARCH(2,4,4)  2  4  4 6364.657431 6430.347888
# GJR-GARCH(2,5,4)  2  4  5 6366.657431 6437.822093
#       GARCH(2,5)  2  5  0 6376.116986 6425.384829
# GJR-GARCH(2,1,5)  2  5  1 6367.658609 6422.400657
# GJR-GARCH(2,2,5)  2  5  2 6362.753677 6422.969930
# GJR-GARCH(2,3,5)  2  5  3 6364.657431 6430.347888
# GJR-GARCH(2,4,5)  2  5  4 6366.657431 6437.822093
# GJR-GARCH(2,5,5)  2  5  5 6368.657432 6445.296299
#       GARCH(3,1)  3  1  0 6368.091162 6400.936391
# GJR-GARCH(3,1,1)  3  1  1 6354.228385 6392.547818
# GJR-GARCH(3,2,1)  3  1  2 6354.977920 6398.771558
# GJR-GARCH(3,3,1)  3  1  3 6341.691316 6390.959160
# GJR-GARCH(3,4,1)  3  1  4 6343.691317 6398.433365
# GJR-GARCH(3,5,1)  3  1  5 6345.691316 6405.907569
#       GARCH(3,2)  3  2  0 6370.091162 6408.410596
# GJR-GARCH(3,1,2)  3  2  1 6356.228384 6400.022023
# GJR-GARCH(3,2,2)  3  2  2 6356.977921 6406.245764
# GJR-GARCH(3,3,2)  3  2  3 6343.691316 6398.433364
# GJR-GARCH(3,4,2)  3  2  4 6345.691316 6405.907569
# GJR-GARCH(3,5,2)  3  2  5 6347.691316 6413.381774
#       GARCH(3,3)  3  3  0 6370.729205 6414.522844
# GJR-GARCH(3,1,3)  3  3  1 6358.228385 6407.496228
# GJR-GARCH(3,2,3)  3  3  2 6358.186737 6412.928785
# GJR-GARCH(3,3,3)  3  3  3 6345.691316 6405.907569
# GJR-GARCH(3,4,3)  3  3  4 6347.691317 6413.381774
# GJR-GARCH(3,5,3)  3  3  5 6349.691317 6420.855979
#       GARCH(3,4)  3  4  0 6372.729205 6421.997048
# GJR-GARCH(3,1,4)  3  4  1 6360.207808 6414.949856
# GJR-GARCH(3,2,4)  3  4  2 6359.012699 6419.228952
# GJR-GARCH(3,3,4)  3  4  3 6347.476600 6413.167057
# GJR-GARCH(3,4,4)  3  4  4 6349.476599 6420.641261
# GJR-GARCH(3,5,4)  3  4  5 6351.476599 6428.115466
#       GARCH(3,5)  3  5  0 6374.729205 6429.471253
# GJR-GARCH(3,1,5)  3  5  1 6362.051404 6422.267657
# GJR-GARCH(3,2,5)  3  5  2 6361.009333 6426.699791
# GJR-GARCH(3,3,5)  3  5  3 6348.614845 6419.779508
# GJR-GARCH(3,4,5)  3  5  4 6350.614845 6427.253712
# GJR-GARCH(3,5,5)  3  5  5 6352.614845 6434.727917
#       GARCH(4,1)  4  1  0 6365.538762 6403.858195
# GJR-GARCH(4,1,1)  4  1  1 6347.740726 6391.534364
# GJR-GARCH(4,2,1)  4  1  2 6344.325385 6393.593229
# GJR-GARCH(4,3,1)  4  1  3 6337.658847 6392.400895
# GJR-GARCH(4,4,1)  4  1  4 6337.356381 6397.572634
# GJR-GARCH(4,5,1)  4  1  5 6339.356381 6405.046838
#       GARCH(4,2)  4  2  0 6367.538762 6411.332400
# GJR-GARCH(4,1,2)  4  2  1 6349.740726 6399.008569
# GJR-GARCH(4,2,2)  4  2  2 6346.325386 6401.067434
# GJR-GARCH(4,3,2)  4  2  3 6339.658846 6399.875099
# GJR-GARCH(4,4,2)  4  2  4 6339.356381 6405.046839
# GJR-GARCH(4,5,2)  4  2  5 6341.356381 6412.521043
#       GARCH(4,3)  4  3  0 6369.139683 6418.407526
# GJR-GARCH(4,1,3)  4  3  1 6351.740726 6406.482774
# GJR-GARCH(4,2,3)  4  3  2 6346.462060 6406.678313
# GJR-GARCH(4,3,3)  4  3  3 6341.593506 6407.283964
# GJR-GARCH(4,4,3)  4  3  4 6341.191083 6412.355746
# GJR-GARCH(4,5,3)  4  3  5 6343.191083 6419.829950
#       GARCH(4,4)  4  4  0 6371.139683 6425.881731
# GJR-GARCH(4,1,4)  4  4  1 6353.740578 6413.956831
# GJR-GARCH(4,2,4)  4  4  2 6346.746910 6412.437368
# GJR-GARCH(4,3,4)  4  4  3 6342.702549 6413.867212
# GJR-GARCH(4,4,4)  4  4  4 6341.887747 6418.526614
# GJR-GARCH(4,5,4)  4  4  5 6343.887747 6426.000819
#       GARCH(4,5)  4  5  0 6373.139683 6433.355936
# GJR-GARCH(4,1,5)  4  5  1 6354.950371 6420.640829
# GJR-GARCH(4,2,5)  4  5  2 6345.100053 6416.264715
# GJR-GARCH(4,3,5)  4  5  3 6341.194969 6417.833836
# GJR-GARCH(4,4,5)  4  5  4 6340.512578 6422.625650
# GJR-GARCH(4,5,5)  4  5  5 6342.512577 6430.099854
#       GARCH(5,1)  5  1  0 6367.150732 6410.944370
# GJR-GARCH(5,1,1)  5  1  1 6349.424833 6398.692677
# GJR-GARCH(5,2,1)  5  1  2 6337.728168 6392.470216
# GJR-GARCH(5,3,1)  5  1  3 6337.629175 6397.845428
# GJR-GARCH(5,4,1)  5  1  4 6337.982864 6403.673322
# GJR-GARCH(5,5,1)  5  1  5 6332.228021 6403.392684
#       GARCH(5,2)  5  2  0 6367.240536 6416.508379
# GJR-GARCH(5,1,2)  5  2  1 6351.424833 6406.166881
# GJR-GARCH(5,2,2)  5  2  2 6337.648387 6397.864640
# GJR-GARCH(5,3,2)  5  2  3 6337.777668 6403.468126
# GJR-GARCH(5,4,2)  5  2  4 6338.391561 6409.556223
# GJR-GARCH(5,5,2)  5  2  5 6334.189669 6410.828536
#       GARCH(5,3)  5  3  0 6367.853059 6422.595108
# GJR-GARCH(5,1,3)  5  3  1 6353.424833 6413.641086
# GJR-GARCH(5,2,3)  5  3  2 6339.462182 6405.152640
# GJR-GARCH(5,3,3)  5  3  3 6339.777669 6410.942331
# GJR-GARCH(5,4,3)  5  3  4 6340.391560 6417.030427
# GJR-GARCH(5,5,3)  5  3  5 6334.247667 6416.360739
#       GARCH(5,4)  5  4  0 6369.853059 6430.069312
# GJR-GARCH(5,1,4)  5  4  1 6355.424833 6421.115291
# GJR-GARCH(5,2,4)  5  4  2 6341.462182 6412.626845
# GJR-GARCH(5,3,4)  5  4  3 6341.777668 6418.416535
# GJR-GARCH(5,4,4)  5  4  4 6342.391560 6424.504632
# GJR-GARCH(5,5,4)  5  4  5 6336.247667 6423.834944
#       GARCH(5,5)  5  5  0 6371.853059 6437.543517
# GJR-GARCH(5,1,5)  5  5  1 6356.819991 6427.984654
# GJR-GARCH(5,2,5)  5  5  2 6336.913542 6413.552409
# GJR-GARCH(5,3,5)  5  5  3 6338.513218 6420.626290
# GJR-GARCH(5,4,5)  5  5  4 6339.996514 6427.583791
# GJR-GARCH(5,5,5)  5  5  5 6334.147573 6427.209055
# Best model (arch):      GJR-GARCH(5,5,1) (AIC=6332.23)
# Best model (arch):      GJR-GARCH(1,1,1) (BIC=6385.39)
# 2nd Best model (arch):      GJR-GARCH(5,5,5) (AIC=6334.15)
# 2nd Best model (arch):      GARCH(1,1) (BIC=6388.08)

# %% [markdown]
# Observations: We select the two best performing GARCH models according to the $\mathrm{BIC}$ which are the:
# - GJR-GARCH(1,1,1)
# - GARCH(1,1)
